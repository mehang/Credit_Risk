# %%
#numpy and pandas for data manipulation
import numpy as np
import pandas as pd

from sklearn.model_selection import KFold

from sklearn.model_selection import StratifiedKFold

from sklearn.ensemble import RandomForestClassifier

from sklearn.model_selection import cross_val_predict

from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer

from sklearn.model_selection import train_test_split
from sklearn import metrics

#sklearn preprocessing for dealing with categorical variables
from sklearn.preprocessing import LabelEncoder

from itertools import product


samples = pd.read_csv('preprocessed-75.csv')

# Create a label encoder object
le = LabelEncoder()
le_count = 0

# Iterate through the columns
for col in samples:
    if samples[col].dtype == 'bool':
        # If 2 or fewer unique categories
        if len(list(samples[col].unique())) <= 2:
            # Train on the training data
            le.fit(samples[col])
            # Transform 
            samples[col] = le.transform(samples[col])
            
            # Keep track of how many columns were label encoded
            le_count += 1
print('%d columns were label encoded.' % le_count)


train_label = samples['TARGET']
print(train_label)



# one-hot encoding of categorical variables
samples = pd.get_dummies(samples)
correlations = samples.corr()['TARGET'].abs().sort_values(ascending=False)
samples = samples.drop(columns = [250:].index.values.tolist())

# %%
train_label = samples['TARGET']
samples = samples.drop(columns=['TARGET'])
# Median imputation of missing values
imputer = SimpleImputer(strategy = 'median')

# Scale each feature to -1 and 1
scaler = StandardScaler()

# Fit on the training data
imputer.fit(samples)

# Transform both training and testing data
samples = imputer.transform(samples)

# Repeat with the scaler
scaler.fit(samples)
samples = scaler.transform(samples)

print('Training data shape: ', samples.shape)

# %%
x_train,x_test, y_train, y_test = train_test_split(samples, train_label, test_size=0.2)

# %%
tot_trees = [100, 200, 300, 400]
for tot_tree in tot_trees:
    kf = StratifiedKFold(n_splits=5, random_state=None, shuffle=False)
    random_forest = RandomForestClassifier(n_estimators = tot_tree, class_weight='balanced', random_state = 50, verbose = 1, n_jobs = -1)
    y_pred = cross_val_predict(estimator=random_forest, X=x_train, y=y_train, cv=kf)
    print("Number of trees - {}  roc - {}".format(tot_tree,metrics.roc_auc_score(y_train, y_pred)))
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   52.3s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:  1.8min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.7s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   41.9s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:  1.6min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.6s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   43.4s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:  1.6min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.6s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   42.2s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:  1.6min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.6s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   41.8s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:  1.6min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.6s finished
# Number of trees - 100  roc - 0.5009077843126325
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   39.3s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 200 out of 200 | elapsed:  3.1min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done 200 out of 200 | elapsed:    1.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   39.4s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 200 out of 200 | elapsed:  2.9min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done 200 out of 200 | elapsed:    1.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   38.4s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 200 out of 200 | elapsed:  2.8min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done 200 out of 200 | elapsed:    1.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   37.8s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 200 out of 200 | elapsed:  2.8min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 200 out of 200 | elapsed:    1.5s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   41.7s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 200 out of 200 | elapsed:  2.9min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done 200 out of 200 | elapsed:    1.2s finished
# Number of trees - 200  roc - 0.5006807409221178
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   37.1s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 300 out of 300 | elapsed:  4.2min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done 300 out of 300 | elapsed:    1.8s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   40.9s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 300 out of 300 | elapsed:  4.5min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 300 out of 300 | elapsed:    2.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   45.2s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-46-19fc1ce81554> in <module>
#       3     kf = StratifiedKFold(n_splits=5, random_state=None, shuffle=False)
#       4     random_forest = RandomForestClassifier(n_estimators = tot_tree, class_weight='balanced', random_state = 50, verbose = 1, n_jobs = -1)
# ----> 5     y_pred = cross_val_predict(estimator=random_forest, X=x_train, y=y_train, cv=kf)
#       6     print("Number of trees - {}  roc - {}".format(tot_tree,metrics.roc_auc_score(y_train, y_pred)))
#
# /usr/local/lib/python3.7/site-packages/sklearn/model_selection/_validation.py in cross_val_predict(estimator, X, y, groups, cv, n_jobs, verbose, fit_params, pre_dispatch, method)
#     753     prediction_blocks = parallel(delayed(_fit_and_predict)(
#     754         clone(estimator), X, y, train, test, verbose, fit_params, method)
# --> 755         for train, test in cv.split(X, y, groups))
#     756
#     757     # Concatenate the predictions
#
# /usr/local/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1005                 self._iterating = self._original_iterator is not None
#    1006
# -> 1007             while self.dispatch_one_batch(iterator):
#    1008                 pass
#    1009
#
# /usr/local/lib/python3.7/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     833                 return False
#     834             else:
# --> 835                 self._dispatch(tasks)
#     836                 return True
#     837
#
# /usr/local/lib/python3.7/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     752         with self._lock:
#     753             job_idx = len(self._jobs)
# --> 754             job = self._backend.apply_async(batch, callback=cb)
#     755             # A job can complete so quickly than its callback is
#     756             # called before we get here, causing self._jobs to
#
# /usr/local/lib/python3.7/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     207     def apply_async(self, func, callback=None):
#     208         """Schedule a func to be run"""
# --> 209         result = ImmediateResult(func)
#     210         if callback:
#     211             callback(result)
#
# /usr/local/lib/python3.7/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     588         # Don't delay the application, to avoid keeping the input
#     589         # arguments in memory
# --> 590         self.results = batch()
#     591
#     592     def get(self):
#
# /usr/local/lib/python3.7/site-packages/joblib/parallel.py in __call__(self)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# /usr/local/lib/python3.7/site-packages/joblib/parallel.py in <listcomp>(.0)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# /usr/local/lib/python3.7/site-packages/sklearn/model_selection/_validation.py in _fit_and_predict(estimator, X, y, train, test, verbose, fit_params, method)
#     839         estimator.fit(X_train, **fit_params)
#     840     else:
# --> 841         estimator.fit(X_train, y_train, **fit_params)
#     842     func = getattr(estimator, method)
#     843     predictions = func(X_test)
#
# /usr/local/lib/python3.7/site-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     381                     verbose=self.verbose, class_weight=self.class_weight,
#     382                     n_samples_bootstrap=n_samples_bootstrap)
# --> 383                 for i, t in enumerate(trees))
#     384
#     385             # Collect newly grown trees
#
# /usr/local/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1015
#    1016             with self._backend.retrieval_context():
# -> 1017                 self.retrieve()
#    1018             # Make sure that we get a last message telling us we are done
#    1019             elapsed_time = time.time() - self._start_time
#
# /usr/local/lib/python3.7/site-packages/joblib/parallel.py in retrieve(self)
#     907             try:
#     908                 if getattr(self._backend, 'supports_timeout', False):
# --> 909                     self._output.extend(job.get(timeout=self.timeout))
#     910                 else:
#     911                     self._output.extend(job.get())
#
# /usr/local/lib/python3.7/site-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     560         AsyncResults.get from multiprocessing."""
#     561         try:
# --> 562             return future.result(timeout=timeout)
#     563         except LokyTimeoutError:
#     564             raise TimeoutError()
#
# /usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py in result(self, timeout)
#     428                 return self.__get_result()
#     429
# --> 430             self._condition.wait(timeout)
#     431
#     432             if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# /usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:

# %%
train_label.value_counts()
# Out:
# 0    282682
# 1     24825
# Name: TARGET, dtype: int64

# %%
print(correlations.head(200))
# Out:
# EXT_SOURCE_3                                            -0.178926
# EXT_SOURCE_2                                            -0.160471
# EXT_SOURCE_1                                            -0.155317
# previous_NAME_CONTRACT_STATUS_Approved_mean             -0.063526
# client_bureau_balance_STATUS_C_sum_mean                 -0.062954
#                                                            ...
# client_credit_AMT_CREDIT_LIMIT_ACTUAL_mean_min          -0.009037
# previous_NAME_SELLER_INDUSTRY_Industry_mean             -0.008887
# client_cash_NAME_CONTRACT_STATUS_Active_sum_mean        -0.008667
# previous_CHANNEL_TYPE_Channel of corporate sales_mean   -0.008606
# previous_NAME_GOODS_CATEGORY_Medical Supplies_sum       -0.008592
# Name: TARGET, Length: 200, dtype: float64

# %%
for val in correlations.abs().sort_values(ascending=False).index.values.tolist():
    print("{} : {}".format(val,correlations[val]))
# Out:
# TARGET : 1.0
# EXT_SOURCE_3 : -0.17892627558435192
# EXT_SOURCE_2 : -0.16047133450758758
# EXT_SOURCE_1 : -0.15531709815567368
# client_credit_CNT_DRAWINGS_CURRENT_max_min : 0.10064765816882223
# bureau_DAYS_CREDIT_mean : 0.08973059094733742
# client_credit_CNT_DRAWINGS_CURRENT_mean_mean : 0.08252014479100929
# DAYS_BIRTH : 0.07824216003637195
# previous_NAME_CONTRACT_STATUS_Refused_mean : 0.07768083802616721
# bureau_CREDIT_ACTIVE_Active_mean : 0.07735592009728258
# bureau_DAYS_CREDIT_min : 0.07524766201015329
# DAYS_EMPLOYED : 0.07495658541678334
# client_credit_AMT_INST_MIN_REGULARITY_mean_min : 0.073593888083776
# bureau_DAYS_CREDIT_UPDATE_mean : 0.06892893766081801
# client_bureau_balance_MONTHS_BALANCE_sum_min : 0.06807162991863505
# bureau_CREDIT_ACTIVE_Active_sum : 0.06713227480456399
# previous_NAME_CONTRACT_STATUS_Refused_sum : 0.06448718697572972
# client_credit_AMT_RECIVABLE_min_min : 0.06360992390964873
# previous_NAME_CONTRACT_STATUS_Approved_mean : -0.06352569361342807
# client_bureau_balance_STATUS_C_sum_mean : -0.06295370415546185
# client_credit_AMT_INST_MIN_REGULARITY_max_min : 0.06273902657595032
# previous_NAME_PRODUCT_TYPE_walk-in_sum : 0.06263180528090216
# client_bureau_balance_STATUS_1_mean_mean : 0.06118292738420565
# client_bureau_balance_STATUS_1_mean_max : 0.061121964712657594
# client_bureau_balance_STATUS_C_sum_max : -0.06108336901633286
# REGION_RATING_CLIENT : 0.05890087937253525
# client_credit_AMT_DRAWINGS_CURRENT_mean_min : 0.05868206513696161
# client_installments_AMT_PAYMENT_min_sum : -0.05839905306871741
# NAME_INCOME_TYPE_Working : 0.05748338262040095
# previous_NAME_PRODUCT_TYPE_walk-in_mean : 0.05741151771656997
# client_credit_MONTHS_BALANCE_sum_sum : 0.057116675832747564
# NAME_EDUCATION_TYPE_Higher education : -0.056592992406724635
# previous_CODE_REJECT_REASON_SCOFR_sum : 0.05628767367716494
# client_bureau_balance_STATUS_C_mean_mean : -0.05593579622487141
# bureau_DAYS_ENDDATE_FACT_min : 0.05588975734918342
# previous_CODE_REJECT_REASON_SCOFR_mean : 0.05586671225416039
# DAYS_LAST_PHONE_CHANGE : 0.05521930350886765
# CODE_GENDER : 0.054710121017631445
# previous_CODE_REJECT_REASON_HC_mean : 0.05454202137802778
# client_bureau_balance_MONTHS_BALANCE_mean_min : 0.05381607320374321
# bureau_DAYS_CREDIT_ENDDATE_sum : 0.053734153701897366
# previous_DAYS_DECISION_min : 0.05343099412438872
# bureau_DAYS_ENDDATE_FACT_mean : 0.05320339693579144
# client_bureau_balance_STATUS_1_mean_sum : 0.05238374764961458
# client_credit_MONTHS_BALANCE_max_sum : 0.05234591047743834
# client_credit_AMT_DRAWINGS_CURRENT_max_min : 0.05199562542171152
# DAYS_ID_PUBLISH : 0.051457257258228584
# client_credit_AMT_CREDIT_LIMIT_ACTUAL_max_sum : -0.051348927088746305
# client_credit_AMT_CREDIT_LIMIT_ACTUAL_sum_sum : -0.05124561927654974
# REG_CITY_NOT_WORK_CITY : 0.05099248334979859
# NAME_EDUCATION_TYPE_Secondary / secondary special : 0.049822436527663945
# client_credit_CNT_DRAWINGS_ATM_CURRENT_sum_min : 0.049818708344007305
# bureau_DAYS_CREDIT_max : 0.049785162016755286
# client_bureau_balance_STATUS_C_sum_sum : -0.04891192028090772
# previous_DAYS_FIRST_DRAWING_mean : -0.048791806811056104
# previous_PRODUCT_COMBINATION_Card Street_sum : 0.047957072278560456
# previous_CODE_REJECT_REASON_HC_sum : 0.04708358001367471
# bureau_DAYS_CREDIT_ENDDATE_mean : 0.0469819265487034
# previous_DAYS_DECISION_mean : 0.0468654737432769
# NAME_INCOME_TYPE_Pensioner : -0.0462113214078983
# previous_NAME_CLIENT_TYPE_New_sum : 0.04605524643023692
# ORGANIZATION_TYPE_XNA : -0.04598897684829635
# FLAG_EMP_PHONE : 0.04598411839565971
# client_credit_AMT_CREDIT_LIMIT_ACTUAL_sum_min : -0.04586488465908129
# previous_NAME_CONTRACT_TYPE_Revolving loans_sum : 0.04562083869935881
# client_installments_DAYS_ENTRY_PAYMENT_min_mean : 0.045381585342058835
# previous_DAYS_FIRST_DRAWING_min : -0.044631808080279875
# previous_DAYS_FIRST_DUE_min : 0.04448314019641602
# bureau_CREDIT_TYPE_Microloan_mean : 0.04443906926649811
# REG_CITY_NOT_LIVE_CITY : 0.04439430211113305
# FLAG_DOCUMENT_3 : 0.04434104644754352
# client_bureau_balance_STATUS_0_mean_mean : 0.044198476222564315
# client_bureau_balance_STATUS_C_mean_max : -0.044118684039228105
# FLOORSMAX_AVG : -0.04400853854768869
# OCCUPATION_TYPE_Laborers : 0.04301723798184508
# bureau_DAYS_CREDIT_UPDATE_min : 0.042863840017762396
# previous_NAME_YIELD_GROUP_XNA_mean : 0.042850640380526314
# EMERGENCYSTATE_MODE_No : -0.04219986280530444
# bureau_DAYS_CREDIT_sum : 0.041999017799555276
# DAYS_REGISTRATION : 0.04197612841215857
# client_installments_AMT_PAYMENT_min_mean : -0.04190795543618955
# previous_RATE_DOWN_PAYMENT_sum : -0.041690086505808445
# previous_NAME_PORTFOLIO_Cards_sum : 0.04150830548061471
# previous_NAME_YIELD_GROUP_low_normal_mean : -0.041133959126554674
# HOUSETYPE_MODE_block of flats : -0.04059223451593096
# previous_CODE_REJECT_REASON_LIMIT_sum : 0.04050568934631784
# previous_PRODUCT_COMBINATION_Card Street_mean : 0.040241795573065835
# previous_RATE_DOWN_PAYMENT_max : -0.040094186605449444
# client_credit_AMT_DRAWINGS_ATM_CURRENT_count_min : -0.04002885420354083
# previous_CODE_REJECT_REASON_LIMIT_mean : 0.03984166262415736
# client_cash_CNT_INSTALMENT_FUTURE_mean_min : 0.039347932989225086
# client_credit_CNT_DRAWINGS_POS_CURRENT_sum_min : 0.038026566673237866
# client_installments_AMT_INSTALMENT_min_sum : -0.03790527191900376
# client_credit_AMT_DRAWINGS_ATM_CURRENT_sum_min : 0.03780472260534994
# OWN_CAR_AGE : 0.037610915780354484
# previous_NAME_YIELD_GROUP_high_mean : 0.037568278634977664
# previous_PRODUCT_COMBINATION_Cash X-Sell: low_mean : -0.03749225177786735
# client_bureau_balance_STATUS_1_mean_min : 0.03733224530729463
# REGION_POPULATION_RELATIVE : -0.03722486669369183
# client_cash_MONTHS_BALANCE_min_sum : 0.037197011298204616
# previous_NAME_YIELD_GROUP_high_sum : 0.036941306748119324
# client_credit_CNT_DRAWINGS_POS_CURRENT_max_sum : 0.03669226889917783
# bureau_DAYS_CREDIT_ENDDATE_max : 0.03658813758651685
# previous_PRODUCT_COMBINATION_Cash X-Sell: high_sum : 0.03630520291801789
# previous_HOUR_APPR_PROCESS_START_mean : -0.035926984679844044
# client_bureau_balance_STATUS_0_sum_mean : -0.035868150674826224
# client_cash_NAME_CONTRACT_STATUS_Active_mean_sum : -0.035862112366403874
# previous_NAME_PAYMENT_TYPE_XNA_mean : 0.034946880750790804
# previous_AMT_ANNUITY_mean : -0.03487029701671986
# previous_CHANNEL_TYPE_AP+ (Cash loan)_mean : 0.03484161807616186
# bureau_CREDIT_TYPE_Credit card_sum : 0.034822392049248335
# client_cash_MONTHS_BALANCE_min_mean : 0.03481061234887106
# previous_CHANNEL_TYPE_AP+ (Cash loan)_sum : 0.03473827615011617
# bureau_CREDIT_TYPE_Credit card_mean : 0.03468564452619522
# previous_DAYS_LAST_DUE_1ST_VERSION_mean : 0.034495258689599566
# client_cash_MONTHS_BALANCE_sum_min : 0.03447555135856189
# bureau_DAYS_CREDIT_ENDDATE_min : 0.03428099152357561
# ELEVATORS_AVG : -0.03420227894409464
# bureau_CREDIT_TYPE_Microloan_sum : 0.03411021129043705
# previous_PRODUCT_COMBINATION_POS industry with interest_mean : -0.033942629481391116
# FLOORSMIN_AVG : -0.033618906337658724
# previous_RATE_DOWN_PAYMENT_mean : -0.033600351236426455
# client_credit_AMT_RECIVABLE_min_sum : 0.03354106760884907
# client_bureau_balance_STATUS_X_sum_mean : -0.0332923663056037
# client_bureau_balance_STATUS_1_sum_mean : 0.03328736172140801
# WALLSMATERIAL_MODE_Panel : -0.03311897824090449
# LIVE_CITY_NOT_WORK_CITY : 0.032516602645477226
# DEF_30_CNT_SOCIAL_CIRCLE : 0.03226131615737433
# previous_AMT_ANNUITY_min : -0.03225017462005551
# client_installments_NUM_INSTALMENT_NUMBER_max_min : 0.03204540806378302
# client_installments_NUM_INSTALMENT_VERSION_min_min : -0.032037363788022785
# client_credit_CNT_INSTALMENT_MATURE_CUM_min_min : -0.03187260314220676
# previous_DAYS_FIRST_DRAWING_count : -0.0318288731238955
# previous_PRODUCT_COMBINATION_Cash Street: high_sum : 0.03176403545325934
# previous_NAME_PORTFOLIO_Cards_mean : 0.03173213513248573
# client_bureau_balance_STATUS_0_mean_min : 0.031530171573119624
# previous_NAME_CASH_LOAN_PURPOSE_Repairs_sum : 0.03148918446639112
# previous_HOUR_APPR_PROCESS_START_min : -0.03142878740148507
# DEF_60_CNT_SOCIAL_CIRCLE : 0.03129501838200975
# client_bureau_balance_STATUS_0_sum_max : -0.031157532408119016
# client_bureau_balance_STATUS_0_mean_sum : 0.0309413267183706
# client_bureau_balance_STATUS_X_sum_max : -0.03091882511925168
# NAME_CONTRACT_TYPE : -0.030885951863760492
# previous_HOUR_APPR_PROCESS_START_max : -0.03084560703922248
# previous_PRODUCT_COMBINATION_POS industry with interest_sum : -0.030824127580300714
# bureau_DAYS_ENDDATE_FACT_count : -0.030490459256899752
# AMT_CREDIT : -0.030371275752961956
# OCCUPATION_TYPE_Drivers : 0.03030255175485176
# client_bureau_balance_MONTHS_BALANCE_sum_max : 0.03024528931194507
# previous_NAME_GOODS_CATEGORY_Furniture_mean : -0.030174385430666136
# previous_PRODUCT_COMBINATION_Cash X-Sell: high_mean : 0.030155498836766454
# previous_PRODUCT_COMBINATION_Cash Street: high_mean : 0.03013823323979876
# client_installments_NUM_INSTALMENT_VERSION_mean_sum : -0.030059850822670507
# client_bureau_balance_STATUS_C_mean_sum : -0.030046762920541065
# NAME_HOUSING_TYPE_With parents : 0.02996501565306532
# client_bureau_balance_STATUS_0_mean_max : 0.029913672271277864
# APARTMENTS_AVG : -0.029501600758400904
# previous_CNT_PAYMENT_max : 0.029444952820382175
# previous_NAME_PORTFOLIO_XNA_mean : 0.029432048641503887
# previous_NAME_CASH_LOAN_PURPOSE_Urgent needs_sum : 0.029353917662873215
# previous_NAME_YIELD_GROUP_low_action_mean : -0.0293416503431863
# client_credit_CNT_INSTALMENT_MATURE_CUM_mean_min : -0.02918312532398073
# ORGANIZATION_TYPE_Self-employed : 0.029137403483197752
# previous_AMT_ANNUITY_max : -0.028963989194949538
# previous_NAME_GOODS_CATEGORY_Furniture_sum : -0.02891896507347585
# previous_NAME_SELLER_INDUSTRY_Furniture_mean : -0.028632005157738893
# FLAG_DOCUMENT_6 : -0.028603126092177127
# NAME_HOUSING_TYPE_House / apartment : -0.028556967033716303
# FLAG_WORK_PHONE : 0.028532808678543405
# previous_NAME_SELLER_INDUSTRY_Connectivity_mean : 0.02846250784750764
# client_bureau_balance_STATUS_C_mean_min : -0.02838240616931577
# bureau_DAYS_CREDIT_UPDATE_max : 0.02823523868649645
# client_installments_NUM_INSTALMENT_VERSION_mean_min : -0.028073591549885934
# previous_NAME_YIELD_GROUP_low_normal_sum : -0.028014720936394902
# client_credit_AMT_PAYMENT_TOTAL_CURRENT_max_min : 0.027979477989150087
# client_cash_CNT_INSTALMENT_FUTURE_mean_mean : 0.027765427775943076
# previous_CNT_PAYMENT_mean : 0.02774435328634048
# previous_CNT_PAYMENT_sum : 0.027721704724227615
# OCCUPATION_TYPE_Low-skill Laborers : 0.027608788607858734
# previous_DAYS_LAST_DUE_min : 0.027608594286161525
# previous_DAYS_LAST_DUE_mean : 0.02740127381462432
# previous_PRODUCT_COMBINATION_Cash Street: middle_sum : 0.027400179690019198
# client_installments_NUM_INSTALMENT_VERSION_mean_mean : -0.027322581521218834
# client_bureau_balance_STATUS_1_sum_max : 0.027124330618105884
# previous_DAYS_LAST_DUE_1ST_VERSION_sum : 0.027071101252597655
# previous_NAME_CLIENT_TYPE_Refreshed_mean : -0.026819132994894482
# NAME_FAMILY_STATUS_Single / not married : 0.02651662225979579
# previous_DAYS_LAST_DUE_1ST_VERSION_min : 0.02635745304713672
# bureau_CREDIT_TYPE_Consumer credit_mean : -0.026259283917926663
# client_installments_AMT_PAYMENT_min_min : -0.025725015614786326
# previous_NAME_SELLER_INDUSTRY_Furniture_sum : -0.02570325789577032
# client_bureau_balance_STATUS_1_sum_sum : 0.025571215391790983
# client_installments_AMT_PAYMENT_sum_max : -0.025456734446595457
# previous_AMT_DOWN_PAYMENT_max : -0.02528959366475296
# client_credit_MONTHS_BALANCE_max_mean : 0.025251381672524578
# NAME_FAMILY_STATUS_Married : -0.025042077991489026
# previous_NAME_YIELD_GROUP_low_action_sum : -0.025026409332507098
# client_credit_CNT_DRAWINGS_CURRENT_min_min : 0.024956784944414973
# client_installments_NUM_INSTALMENT_VERSION_mean_max : -0.024847435130649003
# previous_NAME_SELLER_INDUSTRY_XNA_mean : 0.02481023054487515
# previous_AMT_DOWN_PAYMENT_mean : -0.02462391582748765
# client_bureau_balance_STATUS_1_sum_min : 0.024621832728538656
# client_cash_NAME_CONTRACT_STATUS_Active_mean_max : -0.024594633738156232
# previous_NAME_SELLER_INDUSTRY_Connectivity_sum : 0.024442073934384995
# previous_PRODUCT_COMBINATION_Cash_sum : 0.024375787717984942
# client_installments_AMT_PAYMENT_mean_sum : -0.02428700026716464
# client_installments_AMT_PAYMENT_sum_mean : -0.02423484161700711
# HOUR_APPR_PROCESS_START : -0.024163695725982984
# ORGANIZATION_TYPE_Business Entity Type 3 : 0.023990524524976815
# previous_NAME_CASH_LOAN_PURPOSE_Other_sum : 0.023898309288677925
# FLAG_PHONE : -0.023800516816791174
# previous_AMT_DOWN_PAYMENT_count : -0.02372035306052464
# previous_CHANNEL_TYPE_Contact center_sum : 0.023667489681343554
# client_credit_AMT_DRAWINGS_CURRENT_sum_min : 0.0235252761938349
# NAME_INCOME_TYPE_State servant : -0.023447936313620302
# client_bureau_balance_STATUS_X_sum_sum : -0.023399480276627707
# previous_PRODUCT_COMBINATION_Cash X-Sell: low_sum : -0.023392651102525554
# client_bureau_balance_STATUS_C_sum_min : -0.023322806325586788
# bureau_CREDIT_TYPE_Mortgage_sum : -0.023307673982704787
# previous_PRODUCT_COMBINATION_POS household without interest_sum : -0.023260225331151876
# client_installments_AMT_PAYMENT_mean_mean : -0.023175008796473648
# client_cash_CNT_INSTALMENT_FUTURE_sum_min : 0.023080119702711923
# previous_NAME_CASH_LOAN_PURPOSE_Repairs_mean : 0.02296643990000182
# BASEMENTAREA_AVG : -0.022746816751454388
# client_bureau_balance_MONTHS_BALANCE_max_mean : 0.022709812671620797
# client_credit_AMT_PAYMENT_TOTAL_CURRENT_mean_min : 0.022705009520837396
# FONDKAPREMONT_MODE_reg oper account : -0.02258711259223901
# previous_PRODUCT_COMBINATION_POS household without interest_mean : -0.02257643488330782
# NAME_FAMILY_STATUS_Civil marriage : 0.022498630612670056
# client_credit_CNT_DRAWINGS_CURRENT_max_sum : 0.022470346389791642
# previous_NAME_TYPE_SUITE_Family_mean : -0.02237311386463832
# previous_NAME_SELLER_INDUSTRY_Consumer electronics_mean : -0.022369147554115336
# previous_PRODUCT_COMBINATION_POS industry without interest_sum : -0.022245693412396524
# YEARS_BUILD_AVG : -0.022149831310450733
# previous_PRODUCT_COMBINATION_POS industry without interest_mean : -0.021917902861493206
# FLAG_OWN_CAR : -0.021849824422533335
# OCCUPATION_TYPE_Accountants : -0.02161118353219422
# previous_PRODUCT_COMBINATION_POS mobile with interest_mean : 0.021577975767126976
# client_installments_DAYS_ENTRY_PAYMENT_sum_sum : 0.021537568918966073
# previous_NAME_GOODS_CATEGORY_Consumer Electronics_sum : -0.02132708867213309
# client_credit_NAME_CONTRACT_STATUS_Completed_mean_mean : -0.021314426150119685
# previous_NAME_CLIENT_TYPE_New_mean : 0.02129715379752728
# previous_NAME_PRODUCT_TYPE_XNA_mean : -0.021240099667318567
# previous_CHANNEL_TYPE_Stone_mean : -0.021195411274076315
# client_installments_NUM_INSTALMENT_NUMBER_min_max : -0.02093986223046994
# previous_NAME_SELLER_INDUSTRY_Clothing_mean : -0.020903640816952247
# bureau_CREDIT_TYPE_Mortgage_mean : -0.020868247972226025
# bureau_CREDIT_TYPE_Car loan_sum : -0.020817851661502393
# previous_AMT_GOODS_PRICE_min : -0.02081234168933023
# client_bureau_balance_STATUS_2_mean_sum : 0.020656740283119406
# OCCUPATION_TYPE_Core staff : -0.020376086153352627
# client_credit_NAME_CONTRACT_STATUS_Completed_mean_sum : -0.020373125957506115
# client_bureau_balance_MONTHS_BALANCE_max_min : 0.020335568911816558
# bureau_CREDIT_TYPE_Car loan_mean : -0.020135331580940285
# client_credit_AMT_CREDIT_LIMIT_ACTUAL_min_sum : -0.019960959792961874
# bureau_AMT_CREDIT_SUM_mean : -0.019956992432038412
# client_cash_NAME_CONTRACT_STATUS_Active_sum_sum : -0.019951742401680655
# AMT_REQ_CREDIT_BUREAU_YEAR : 0.019933843256771177
# client_cash_CNT_INSTALMENT_min_min : 0.019838406936736712
# ORGANIZATION_TYPE_Construction : 0.01979129537347604
# NAME_HOUSING_TYPE_Rented apartment : 0.019766735959107613
# previous_NAME_SELLER_INDUSTRY_Clothing_sum : -0.019761323028611222
# bureau_AMT_CREDIT_SUM_max : -0.019737998057939514
# previous_DAYS_DECISION_sum : 0.019692816328968195
# bureau_DAYS_ENDDATE_FACT_max : 0.01964737935975088
# client_cash_NAME_CONTRACT_STATUS_Completed_mean_sum : -0.01954549040065954
# OCCUPATION_TYPE_Sales staff : 0.01953597486254038
# client_cash_NAME_CONTRACT_STATUS_Completed_mean_max : -0.01946728423965475
# previous_AMT_CREDIT_min : -0.019418110457023696
# client_cash_NAME_CONTRACT_STATUS_Completed_mean_min : 0.019396850670574162
# NAME_FAMILY_STATUS_Widow : -0.01939538767754923
# client_credit_AMT_PAYMENT_CURRENT_min_sum : 0.0193564769619748
# previous_NAME_GOODS_CATEGORY_Consumer Electronics_mean : -0.019336229299846755
# client_credit_CNT_DRAWINGS_ATM_CURRENT_min_sum : 0.01924887516571887
# client_bureau_balance_STATUS_0_sum_sum : -0.01920809193810272
# CNT_CHILDREN : 0.019189112947519276
# ENTRANCES_AVG : -0.01917537920860322
# previous_NAME_CASH_LOAN_PURPOSE_Other_mean : 0.019143752836623177
# previous_NAME_CASH_LOAN_PURPOSE_Urgent needs_mean : 0.019126030056333187
# previous_DAYS_FIRST_DUE_max : -0.01906129686150683
# client_cash_CNT_INSTALMENT_FUTURE_min_min : 0.019009452111855424
# client_bureau_balance_STATUS_5_mean_mean : 0.018951413219794346
# client_bureau_balance_STATUS_5_mean_min : 0.018918536465483273
# previous_CHANNEL_TYPE_Credit and cash offices_sum : 0.018890817469331238
# previous_NAME_SELLER_INDUSTRY_Consumer electronics_sum : -0.018793441619104206
# OCCUPATION_TYPE_Managers : -0.018649070442255035
# previous_PRODUCT_COMBINATION_Cash_mean : 0.018578561477424486
# client_bureau_balance_STATUS_2_mean_mean : 0.018551633020424563
# COMMONAREA_AVG : -0.018551216655337547
# client_cash_CNT_INSTALMENT_FUTURE_min_mean : 0.018525596113532872
# previous_PRODUCT_COMBINATION_Cash Street: middle_mean : 0.01841636968615428
# previous_CHANNEL_TYPE_Stone_sum : -0.018390921991344893
# previous_NAME_GOODS_CATEGORY_Mobile_mean : 0.018337522031009114
# previous_NAME_PRODUCT_TYPE_x-sell_mean : -0.01825284924906438
# client_cash_CNT_INSTALMENT_FUTURE_mean_max : 0.01792644253075319
# previous_PRODUCT_COMBINATION_Card X-Sell_sum : 0.01782990569409667
# client_bureau_balance_STATUS_2_mean_max : 0.017827116057053376
# client_cash_MONTHS_BALANCE_sum_sum : 0.017785625775287157
# ORGANIZATION_TYPE_Transport: type 3 : 0.017551635080560082
# client_bureau_balance_STATUS_0_sum_min : -0.017523535196127586
# client_bureau_balance_STATUS_3_mean_mean : 0.01746438092437913
# client_installments_AMT_PAYMENT_sum_sum : -0.01729313607677183
# client_bureau_balance_STATUS_3_sum_mean : 0.017156298702826662
# previous_NAME_TYPE_SUITE_Children_sum : -0.017018653578955645
# client_cash_NAME_CONTRACT_STATUS_Active_sum_min : 0.016958169195182848
# previous_AMT_DOWN_PAYMENT_min : -0.016950801688518084
# client_bureau_balance_STATUS_3_mean_max : 0.016543744541364914
# bureau_CREDIT_ACTIVE_Sold_mean : 0.0165340922661338
# client_installments_NUM_INSTALMENT_VERSION_sum_max : -0.016474803970262394
# client_bureau_balance_STATUS_4_mean_max : 0.016450770309167546
# client_credit_AMT_DRAWINGS_POS_CURRENT_sum_sum : -0.016443467671166605
# previous_DAYS_DECISION_max : 0.016401185545121592
# previous_NAME_TYPE_SUITE_Children_mean : -0.016374477687451382
# client_bureau_balance_STATUS_4_sum_mean : 0.016277779077909293
# client_bureau_balance_STATUS_4_mean_mean : 0.016215789660048927
# previous_AMT_CREDIT_mean : -0.016111996415226152
# previous_NAME_CASH_LOAN_PURPOSE_Payments on other loans_sum : 0.016043824182397432
# previous_NAME_YIELD_GROUP_middle_mean : -0.016004319952557418
# client_installments_NUM_INSTALMENT_NUMBER_mean_min : 0.015918001925157854
# previous_NAME_TYPE_SUITE_Family_sum : -0.0158466700253384
# client_bureau_balance_STATUS_4_mean_sum : 0.01568095959004755
# client_bureau_balance_STATUS_3_mean_sum : 0.015656508268789567
# previous_NAME_PORTFOLIO_Cash_sum : 0.01563338353337446
# previous_PRODUCT_COMBINATION_Cash X-Sell: middle_mean : -0.015556656112091893
# previous_NFLAG_INSURED_ON_APPROVAL_sum : -0.015540189143530773
# client_installments_NUM_INSTALMENT_VERSION_sum_sum : -0.015482235954587125
# client_bureau_balance_STATUS_4_sum_sum : 0.015401264806074719
# bureau_AMT_ANNUITY_count : 0.015384583010604875
# previous_NAME_SELLER_INDUSTRY_Construction_mean : -0.015247856851369875
# client_credit_AMT_DRAWINGS_CURRENT_sum_sum : -0.015191965176680275
# client_bureau_balance_STATUS_5_sum_min : 0.015188925601079794
# client_bureau_balance_STATUS_4_sum_max : 0.015159749849577494
# client_cash_NAME_CONTRACT_STATUS_Signed_mean_min : 0.015125542720346618
# previous_WEEKDAY_APPR_PROCESS_START_THURSDAY_sum : 0.015116877571572459
# previous_NAME_CASH_LOAN_PURPOSE_Car repairs_sum : 0.014915171213755622
# previous_RATE_DOWN_PAYMENT_min : -0.014784921996760868
# previous_CODE_REJECT_REASON_SCO_sum : 0.014677828249856752
# OCCUPATION_TYPE_Security staff : 0.014647826775120476
# client_bureau_balance_STATUS_X_sum_min : -0.014556613235366816
# client_installments_AMT_PAYMENT_min_max : -0.014484400768723283
# client_credit_CNT_DRAWINGS_CURRENT_min_sum : 0.014380285748968576
# previous_WEEKDAY_APPR_PROCESS_START_MONDAY_sum : 0.014326108186586735
# ANNUITY_INCOME_PERCENT : 0.014262368797826422
# previous_PRODUCT_COMBINATION_POS mobile with interest_sum : 0.014261144309252703
# client_cash_NAME_CONTRACT_STATUS_Signed_sum_min : 0.014213801946058488
# previous_NAME_SELLER_INDUSTRY_Construction_sum : -0.014164890615105159
# client_bureau_balance_STATUS_3_sum_sum : 0.014155117149135072
# previous_NAME_CLIENT_TYPE_Refreshed_sum : -0.014138310174392378
# bureau_AMT_CREDIT_SUM_sum : -0.01405657301531746
# client_bureau_balance_STATUS_2_sum_sum : 0.013815043566418684
# client_bureau_balance_STATUS_5_mean_sum : 0.013775562808726905
# OCCUPATION_TYPE_High skill tech staff : -0.013766432059547275
# client_bureau_balance_STATUS_5_mean_max : 0.013727563876570016
# client_bureau_balance_STATUS_3_sum_max : 0.013718790393538717
# ORGANIZATION_TYPE_School : -0.013671828019425144
# client_installments_NUM_INSTALMENT_VERSION_sum_mean : -0.013649166976884168
# client_installments_NUM_INSTALMENT_NUMBER_min_mean : -0.013609486341232659
# NONLIVINGAREA_AVG : -0.01357950405636665
# client_bureau_balance_STATUS_2_sum_mean : 0.013520697131345823
# client_credit_CNT_DRAWINGS_POS_CURRENT_min_sum : 0.013222267227486916
# client_installments_AMT_PAYMENT_mean_min : -0.013021683280875182
# previous_NAME_CONTRACT_TYPE_XNA_sum : 0.01300940442002788
# client_credit_AMT_DRAWINGS_POS_CURRENT_max_sum : -0.012974354799556402
# previous_PRODUCT_COMBINATION_Cash Street: low_sum : 0.012855298038658657
# client_cash_NAME_CONTRACT_STATUS_Completed_sum_min : 0.012851424978865163
# AMT_ANNUITY : -0.012818497233844761
# client_bureau_balance_MONTHS_BALANCE_max_sum : 0.012718985022809914
# CREDIT_TERM : 0.012702987265659318
# WALLSMATERIAL_MODE_Stone, brick : -0.012654098050459322
# previous_WEEKDAY_APPR_PROCESS_START_TUESDAY_sum : 0.012569456130556227
# previous_NAME_CASH_LOAN_PURPOSE_XNA_sum : 0.012541138664255031
# client_credit_NAME_CONTRACT_STATUS_Sent proposal_mean_mean : -0.012526883962747279
# previous_NAME_CASH_LOAN_PURPOSE_Building a house or an annex_sum : 0.012482878350507208
# AMT_REQ_CREDIT_BUREAU_MON : -0.012460349945703997
# client_cash_NAME_CONTRACT_STATUS_Returned to the store_sum_mean : 0.012361850552806293
# previous_NAME_CASH_LOAN_PURPOSE_Payments on other loans_mean : 0.012261062917006104
# previous_WEEKDAY_APPR_PROCESS_START_FRIDAY_sum : 0.012240464370513657
# OCCUPATION_TYPE_Cooking staff : 0.012221355268583426
# previous_NAME_CONTRACT_STATUS_Canceled_mean : 0.012199847739798406
# previous_CODE_REJECT_REASON_SCO_mean : 0.012184672168085721
# previous_CHANNEL_TYPE_Contact center_mean : 0.012146622700569713
# client_cash_NAME_CONTRACT_STATUS_Active_mean_min : 0.012095598528592608
# bureau_CREDIT_ACTIVE_Sold_sum : 0.012064811149238783
# client_cash_NAME_CONTRACT_STATUS_Returned to the store_mean_mean : 0.012035885939891343
# NAME_INCOME_TYPE_Commercial associate : -0.011905565445634455
# client_credit_AMT_INST_MIN_REGULARITY_max_sum : -0.01188279499932144
# previous_PRODUCT_COMBINATION_POS household with interest_sum : -0.01186555228899359
# client_credit_AMT_DRAWINGS_ATM_CURRENT_max_sum : -0.011764238756123722
# NAME_EDUCATION_TYPE_Lower secondary : 0.011746483350126303
# previous_NFLAG_INSURED_ON_APPROVAL_min : 0.011685814895047187
# FLAG_DOCUMENT_16 : -0.011615064988650585
# previous_NAME_CASH_LOAN_PURPOSE_Car repairs_mean : 0.011601975596321494
# FLAG_DOCUMENT_13 : -0.011583458494692363
# previous_NAME_CASH_LOAN_PURPOSE_Medicine_sum : 0.011582924247096713
# previous_NAME_TYPE_SUITE_Unaccompanied_mean : -0.011524199917078854
# bureau_AMT_CREDIT_SUM_LIMIT_mean : -0.011447004046064602
# previous_PRODUCT_COMBINATION_POS household with interest_mean : -0.011430322558305905
# client_credit_CNT_DRAWINGS_POS_CURRENT_sum_sum : 0.011369888963259057
# client_cash_NAME_CONTRACT_STATUS_Returned to the store_mean_max : 0.011340886203880777
# FONDKAPREMONT_MODE_org spec account : -0.01128535092319975
# FONDKAPREMONT_MODE_reg oper spec account : -0.011253663643579997
# client_installments_NUM_INSTALMENT_VERSION_max_min : -0.011206776692486493
# previous_WEEKDAY_APPR_PROCESS_START_WEDNESDAY_sum : 0.011033561423475275
# previous_NAME_CASH_LOAN_PURPOSE_Buying a used car_sum : 0.010969263862167473
# previous_NAME_GOODS_CATEGORY_Mobile_sum : 0.010939610170570787
# client_credit_AMT_DRAWINGS_CURRENT_min_min : 0.010937721970947265
# client_bureau_balance_STATUS_2_sum_max : 0.010898819917890825
# LANDAREA_AVG : -0.01088710150294817
# previous_CNT_PAYMENT_min : -0.010793108572045603
# client_credit_AMT_DRAWINGS_ATM_CURRENT_min_sum : 0.010791585441925032
# bureau_AMT_CREDIT_SUM_min : -0.010764901159880885
# previous_DAYS_LAST_DUE_sum : 0.010715039500363809
# previous_NFLAG_INSURED_ON_APPROVAL_max : -0.01070615801484993
# previous_NAME_CASH_LOAN_PURPOSE_Building a house or an annex_mean : 0.010628250647052797
# bureau_AMT_CREDIT_SUM_OVERDUE_max : 0.010615233854372047
# ORGANIZATION_TYPE_Medicine : -0.010614993270197945
# client_cash_NAME_CONTRACT_STATUS_Signed_mean_mean : 0.010491817897537975
# client_bureau_balance_STATUS_3_sum_min : 0.010431519098404167
# previous_CHANNEL_TYPE_Credit and cash offices_mean : 0.01035923989940174
# ORGANIZATION_TYPE_Restaurant : 0.010265290664507995
# previous_FLAG_LAST_APPL_PER_CONTRACT_N_sum : 0.010238208396778622
# client_installments_AMT_PAYMENT_mean_max : -0.01021723437999145
# client_bureau_balance_STATUS_5_sum_max : 0.010163183846885563
# client_bureau_balance_STATUS_5_sum_sum : 0.010159925175195641
# client_cash_NAME_CONTRACT_STATUS_Returned to the store_sum_min : 0.010114758640849947
# previous_NAME_GOODS_CATEGORY_Construction Materials_mean : -0.010063219888353899
# ORGANIZATION_TYPE_Military : -0.010057575735175997
# previous_PRODUCT_COMBINATION_Card X-Sell_mean : 0.010030355346802751
# previous_NAME_GOODS_CATEGORY_Construction Materials_sum : -0.01001731494448712
# ORGANIZATION_TYPE_Police : -0.009886814756388465
# previous_WEEKDAY_APPR_PROCESS_START_SUNDAY_mean : -0.009745935365685063
# YEARS_BEGINEXPLUATATION_AVG : -0.009727353375308048
# ORGANIZATION_TYPE_Industry: type 3 : 0.009701505288280251
# ORGANIZATION_TYPE_Bank : -0.009609736694504895
# ORGANIZATION_TYPE_Security Ministries : -0.009470634123112073
# FLAG_DOCUMENT_14 : -0.009464036716623554
# bureau_AMT_CREDIT_SUM_LIMIT_sum : -0.009419696230057896
# WALLSMATERIAL_MODE_Monolithic : -0.009383963534540149
# client_credit_AMT_DRAWINGS_ATM_CURRENT_sum_sum : -0.00934548448021302
# CNT_FAM_MEMBERS : 0.009310394410111875
# previous_CHANNEL_TYPE_Regional / Local_sum : -0.009284694898859946
# previous_NAME_GOODS_CATEGORY_Medical Supplies_mean : -0.00927248949438305
# previous_NAME_GOODS_CATEGORY_Audio/Video_sum : -0.009225445989991246
# previous_NAME_CASH_LOAN_PURPOSE_Medicine_mean : 0.00921540756524002
# client_bureau_balance_STATUS_4_sum_min : 0.009168492496156587
# OBS_30_CNT_SOCIAL_CIRCLE : 0.00913551177113779
# client_cash_NAME_CONTRACT_STATUS_Returned to the store_mean_sum : 0.00910287261566855
# previous_CHANNEL_TYPE_Regional / Local_mean : -0.009070298207849003
# client_credit_AMT_CREDIT_LIMIT_ACTUAL_mean_min : -0.009037069004304017
# ORGANIZATION_TYPE_Trade: type 3 : 0.00891056752647634
# previous_NAME_SELLER_INDUSTRY_Industry_mean : -0.008886754291651623
# client_cash_NAME_CONTRACT_STATUS_Returned to the store_mean_min : 0.008791987440136293
# NAME_INCOME_TYPE_Unemployed : 0.008784227805731178
# client_cash_CNT_INSTALMENT_FUTURE_min_max : 0.008783755365643318
# previous_AMT_GOODS_PRICE_count : 0.008736960367324088
# client_cash_NAME_CONTRACT_STATUS_Active_sum_mean : -0.008667018069603615
# previous_NAME_CONTRACT_TYPE_XNA_mean : 0.008606750900218943
# previous_CHANNEL_TYPE_Channel of corporate sales_mean : -0.008605872595108158
# previous_NAME_GOODS_CATEGORY_Medical Supplies_sum : -0.008592407706796971
# client_bureau_balance_STATUS_3_mean_min : 0.008563335974387392
# previous_FLAG_LAST_APPL_PER_CONTRACT_N_mean : 0.008527071139682334
# OCCUPATION_TYPE_Medicine staff : -0.008515079953049494
# previous_WEEKDAY_APPR_PROCESS_START_SATURDAY_mean : -0.00845358472062322
# previous_AMT_CREDIT_max : -0.00843575084034002
# client_cash_NAME_CONTRACT_STATUS_Returned to the store_sum_sum : 0.008304264702387045
# NAME_TYPE_SUITE_Unaccompanied : 0.008300375609001516
# bureau_AMT_CREDIT_MAX_OVERDUE_count : 0.008226764957120233
# NAME_TYPE_SUITE_Family : -0.008225023790399737
# client_bureau_balance_STATUS_X_mean_sum : 0.00821807000580341
# previous_NAME_CASH_LOAN_PURPOSE_Gasification / water supply_mean : 0.00817001906607492
# ORGANIZATION_TYPE_Trade: type 7 : 0.008168892085269122
# bureau_CREDIT_DAY_OVERDUE_mean : 0.008118348441322233
# previous_NAME_SELLER_INDUSTRY_Auto technology_sum : 0.008099847668334662
# FLAG_DOCUMENT_8 : -0.008041540991203772
# client_cash_NAME_CONTRACT_STATUS_Active_mean_mean : -0.008030174003639942
# client_credit_CNT_DRAWINGS_OTHER_CURRENT_max_sum : -0.008025812940483977
# previous_NAME_CASH_LOAN_PURPOSE_Gasification / water supply_sum : 0.008013388239025228
# FLAG_DOCUMENT_18 : -0.007952739053103447
# client_installments_AMT_PAYMENT_sum_min : -0.007949159461736636
# WALLSMATERIAL_MODE_Wooden : 0.007945846216204177
# client_credit_AMT_DRAWINGS_OTHER_CURRENT_sum_min : 0.007941944528845377
# ORGANIZATION_TYPE_Agriculture : 0.00790077717369764
# client_cash_NAME_CONTRACT_STATUS_Signed_sum_mean : 0.007866171901226795
# OCCUPATION_TYPE_Waiters/barmen staff : 0.007801652641241113
# CREDIT_INCOME_PERCENT : -0.007729364233482874
# previous_NAME_GOODS_CATEGORY_Other_sum : -0.007675523697946151
# ORGANIZATION_TYPE_University : -0.007672092070744712
# previous_NAME_CASH_LOAN_PURPOSE_Purchase of electronic equipment_sum : 0.007626385930979125
# bureau_CREDIT_DAY_OVERDUE_min : 0.007573030839014874
# previous_NAME_CASH_LOAN_PURPOSE_Buying a used car_mean : 0.007555124669611463
# ORGANIZATION_TYPE_Government : -0.007521129137740541
# client_credit_CNT_DRAWINGS_ATM_CURRENT_max_sum : -0.007487251229514263
# client_credit_AMT_PAYMENT_TOTAL_CURRENT_max_sum : -0.007336539769888614
# previous_NAME_SELLER_INDUSTRY_Industry_sum : -0.007324665405303825
# previous_NAME_GOODS_CATEGORY_Audio/Video_mean : -0.007253124346180484
# ORGANIZATION_TYPE_Security : 0.007225678568825017
# client_cash_NAME_CONTRACT_STATUS_Demand_mean_mean : 0.007200798085700146
# previous_NAME_GOODS_CATEGORY_Tourism_sum : -0.0071588931844281745
# bureau_AMT_CREDIT_SUM_OVERDUE_mean : 0.0071504984653726076
# previous_DAYS_FIRST_DUE_sum : 0.007083994966497489
# client_cash_SK_DPD_max_min : 0.007051966324886586
# previous_NAME_PRODUCT_TYPE_XNA_sum : 0.0070414331011173946
# OCCUPATION_TYPE_Cleaning staff : 0.006978415045031199
# client_cash_SK_DPD_mean_min : 0.0069628159300194345
# previous_CODE_REJECT_REASON_XNA_sum : 0.006949914182833037
# REG_REGION_NOT_WORK_REGION : 0.006941022446750541
# client_credit_CNT_DRAWINGS_ATM_CURRENT_sum_sum : -0.0068857095928573885
# previous_NAME_GOODS_CATEGORY_Tourism_mean : -0.006858483510472901
# client_cash_CNT_INSTALMENT_FUTURE_min_sum : 0.006825670361495408
# bureau_CREDIT_CURRENCY_currency 2_mean : -0.006821523655798001
# WALLSMATERIAL_MODE_Block : -0.006777498590152209
# previous_AMT_ANNUITY_sum : -0.0067288743071912405
# previous_DAYS_LAST_DUE_max : 0.006660640205089238
# client_credit_SK_DPD_DEF_mean_mean : 0.006660059777686262
# previous_NAME_CASH_LOAN_PURPOSE_Furniture_sum : 0.006588894496736008
# FLAG_DOCUMENT_15 : -0.006535795521861065
# client_cash_SK_DPD_DEF_mean_mean : 0.00649552199240003
# client_bureau_balance_STATUS_2_sum_min : 0.006491890718646689
# client_credit_NAME_CONTRACT_STATUS_Signed_sum_min : -0.006459799229360367
# previous_NAME_GOODS_CATEGORY_Homewares_mean : -0.0064359783165546715
# ORGANIZATION_TYPE_Industry: type 1 : 0.006402119704114735
# client_bureau_balance_STATUS_4_mean_min : 0.006391773083856249
# client_cash_NAME_CONTRACT_STATUS_Amortized debt_mean_mean : 0.006388534510049253
# previous_NAME_CASH_LOAN_PURPOSE_Everyday expenses_sum : 0.006152183843093013
# FLAG_OWN_REALTY : -0.006145847256910038
# previous_NAME_PORTFOLIO_Cash_mean : 0.006104278523908069
# client_bureau_balance_STATUS_2_mean_min : 0.006052156417398797
# previous_NAME_GOODS_CATEGORY_Homewares_sum : -0.006050400027395708
# bureau_CREDIT_TYPE_Loan for working capital replenishment_sum : 0.006017935456136454
# previous_NAME_GOODS_CATEGORY_Vehicles_sum : 0.006017393577394708
# bureau_CREDIT_CURRENCY_currency 2_sum : -0.006002996568709228
# ORGANIZATION_TYPE_Transport: type 4 : 0.0059285012463642815
# client_cash_MONTHS_BALANCE_sum_max : -0.005866949163923586
# client_cash_CNT_INSTALMENT_FUTURE_mean_sum : -0.005810989369778879
# client_cash_NAME_CONTRACT_STATUS_Demand_mean_min : 0.005796281409961613
# ORGANIZATION_TYPE_Trade: type 6 : -0.005787788102141558
# previous_WEEKDAY_APPR_PROCESS_START_MONDAY_mean : 0.00577736020314835
# ORGANIZATION_TYPE_Kindergarten : -0.005758664015387994
# previous_PRODUCT_COMBINATION_Cash X-Sell: middle_sum : -0.005661706467191737
# previous_NAME_GOODS_CATEGORY_Medicine_mean : -0.005657201186177914
# previous_NAME_SELLER_INDUSTRY_Auto technology_mean : 0.005629086863147598
# REG_REGION_NOT_LIVE_REGION : 0.005575470256357997
# client_cash_SK_DPD_DEF_min_mean : 0.005530234916894416
# bureau_CREDIT_DAY_OVERDUE_max : 0.005492604498046639
# client_cash_SK_DPD_min_min : 0.005444361049324785
# ORGANIZATION_TYPE_Industry: type 12 : -0.005444334734431418
# client_cash_SK_DPD_mean_mean : 0.005435466862274057
# previous_NAME_CASH_LOAN_PURPOSE_Wedding / gift / holiday_sum : 0.00542290589763824
# FLAG_DOCUMENT_2 : 0.005417122311295358
# ORGANIZATION_TYPE_Industry: type 9 : -0.005378923685186636
# HOUSETYPE_MODE_specific housing : 0.005310783119735809
# previous_NAME_TYPE_SUITE_Other_A_mean : 0.005298175782536131
# NAME_EDUCATION_TYPE_Academic degree : -0.005294377290835794
# previous_NAME_TYPE_SUITE_Spouse, partner_mean : -0.005277527705359158
# WEEKDAY_APPR_PROCESS_START_MONDAY : -0.00515099311658885
# client_bureau_balance_MONTHS_BALANCE_max_max : 0.005119414108023984
# client_installments_AMT_INSTALMENT_max_mean : 0.00510641093376787
# NAME_HOUSING_TYPE_Office apartment : -0.005103281314381849
# previous_NAME_GOODS_CATEGORY_Photo / Cinema Equipment_sum : -0.005055495230946454
# OCCUPATION_TYPE_Private service staff : -0.005047262800737783
# client_cash_NAME_CONTRACT_STATUS_Amortized debt_mean_min : 0.005018799100600921
# previous_NAME_CASH_LOAN_PURPOSE_Hobby_sum : 0.004933073493359107
# NAME_TYPE_SUITE_Other_B : 0.004908791482964348
# EMERGENCYSTATE_MODE_Yes : 0.004828531836339768
# previous_WEEKDAY_APPR_PROCESS_START_FRIDAY_mean : 0.004807975099609775
# bureau_AMT_CREDIT_SUM_LIMIT_min : -0.004778797016806483
# previous_NAME_CASH_LOAN_PURPOSE_Business development_sum : 0.0047781972746898235
# previous_NAME_CASH_LOAN_PURPOSE_Buying a home_sum : 0.004759864464892745
# previous_NAME_GOODS_CATEGORY_Other_mean : -0.0047572978160712156
# previous_NAME_CASH_LOAN_PURPOSE_Wedding / gift / holiday_mean : 0.004742571974552842
# client_cash_NAME_CONTRACT_STATUS_Canceled_sum_sum : 0.004730140810748751
# NAME_INCOME_TYPE_Maternity leave : 0.004725857472698374
# client_cash_SK_DPD_DEF_min_min : 0.0047016290844738295
# WEEKDAY_APPR_PROCESS_START_TUESDAY : 0.004698855920646655
# bureau_CREDIT_ACTIVE_Bad debt_mean : 0.004638109854181518
# previous_NAME_CLIENT_TYPE_Repeater_mean : -0.004618987400490121
# previous_NAME_SELLER_INDUSTRY_Tourism_mean : -0.004563302963216859
# previous_NAME_GOODS_CATEGORY_Medicine_sum : -0.004551599705675967
# bureau_CREDIT_TYPE_Loan for the purchase of equipment_sum : 0.004494866336184438
# previous_DAYS_FIRST_DUE_mean : 0.004488690748051558
# previous_NAME_CASH_LOAN_PURPOSE_Education_sum : 0.004437392303077592
# previous_NAME_CASH_LOAN_PURPOSE_Buying a holiday home / land_mean : 0.004415947830254347
# previous_NAME_YIELD_GROUP_middle_sum : -0.004390014899152095
# previous_NAME_GOODS_CATEGORY_Computers_mean : -0.004356490602171678
# previous_NAME_GOODS_CATEGORY_Photo / Cinema Equipment_mean : -0.004355321417355991
# FLAG_DOCUMENT_9 : -0.004352652247632549
# client_credit_CNT_DRAWINGS_CURRENT_sum_sum : 0.00429730088403131
# previous_NAME_GOODS_CATEGORY_Gardening_sum : -0.004292476622536699
# previous_NAME_SELLER_INDUSTRY_Tourism_sum : -0.0042759541750726346
# previous_NAME_GOODS_CATEGORY_Gardening_mean : -0.004255450738573313
# previous_NAME_CASH_LOAN_PURPOSE_Journey_sum : 0.004236043425070542
# FLAG_DOCUMENT_11 : -0.0042295937505302805
# previous_NAME_SELLER_INDUSTRY_MLM partners_mean : -0.004195309180733405
# client_cash_NAME_CONTRACT_STATUS_Demand_sum_min : 0.004089555877626885
# previous_CHANNEL_TYPE_Channel of corporate sales_sum : -0.004082143332847863
# previous_NAME_CASH_LOAN_PURPOSE_XAP_sum : 0.004075379777259209
# ORGANIZATION_TYPE_Industry: type 4 : 0.004074021236595172
# previous_WEEKDAY_APPR_PROCESS_START_WEDNESDAY_mean : 0.004044924489025364
# previous_NAME_GOODS_CATEGORY_Auto Accessories_sum : 0.004016136277368059
# bureau_CREDIT_ACTIVE_Bad debt_sum : 0.0040028183844802515
# previous_CODE_REJECT_REASON_XNA_mean : 0.003991487467335369
# AMT_INCOME_TOTAL : -0.003981577066712728
# bureau_CNT_CREDIT_PROLONG_max : 0.003950016109546931
# previous_NAME_CASH_LOAN_PURPOSE_Hobby_mean : 0.00392380417817174
# previous_PRODUCT_COMBINATION_POS other with interest_mean : -0.003916444618378113
# client_installments_AMT_INSTALMENT_max_min : 0.0039012953238194946
# ORGANIZATION_TYPE_Services : -0.0038712482264555304
# client_installments_NUM_INSTALMENT_VERSION_min_max : -0.003862120969164291
# ORGANIZATION_TYPE_Insurance : -0.0038496957771933667
# client_credit_AMT_DRAWINGS_POS_CURRENT_sum_min : -0.0037883784627218615
# ORGANIZATION_TYPE_Other : -0.0037847118404665415
# bureau_CREDIT_TYPE_Loan for business development_sum : -0.003783008101849149
# FLAG_DOCUMENT_21 : 0.003708556595613523
# previous_NAME_GOODS_CATEGORY_Vehicles_mean : 0.0036802160524111597
# previous_NAME_CASH_LOAN_PURPOSE_Buying a holiday home / land_sum : 0.00367695654267209
# client_cash_SK_DPD_DEF_mean_min : 0.0036188955452935156
# previous_NAME_GOODS_CATEGORY_Fitness_mean : -0.0036164335117468277
# client_credit_AMT_DRAWINGS_OTHER_CURRENT_sum_sum : -0.0035242715116855553
# previous_NAME_GOODS_CATEGORY_Jewelry_sum : 0.0034913206625528104
# previous_NAME_CASH_LOAN_PURPOSE_Education_mean : 0.003425359692314865
# bureau_AMT_CREDIT_SUM_LIMIT_count : 0.003424081759937566
# previous_WEEKDAY_APPR_PROCESS_START_SATURDAY_sum : 0.0034136725712591146
# ORGANIZATION_TYPE_Hotel : -0.0034099071983583903
# previous_NAME_CASH_LOAN_PURPOSE_Purchase of electronic equipment_mean : 0.003404296697606776
# FLAG_DOCUMENT_17 : -0.003377634037701398
# ORGANIZATION_TYPE_Transport: type 1 : -0.003375343723547598
# client_cash_MONTHS_BALANCE_min_max : -0.003370166480798683
# ORGANIZATION_TYPE_Realtor : 0.003338943146445122
# NAME_HOUSING_TYPE_Municipal apartment : 0.003333813848561125
# previous_CHANNEL_TYPE_Car dealer_sum : -0.003324562474129267
# ORGANIZATION_TYPE_Cleaning : 0.003289849259374434
# ORGANIZATION_TYPE_Culture : -0.0032651287662864357
# previous_WEEKDAY_APPR_PROCESS_START_THURSDAY_mean : 0.003256242814456448
# client_credit_AMT_INST_MIN_REGULARITY_min_sum : -0.0032142295290244916
# client_credit_SK_DPD_mean_mean : -0.0031947922784405077
# previous_NAME_CLIENT_TYPE_XNA_sum : 0.003192169140221712
# client_cash_SK_DPD_min_mean : 0.003177714122335216
# client_credit_AMT_INST_MIN_REGULARITY_min_min : 0.003177469993193575
# NONLIVINGAPARTMENTS_AVG : -0.0031769439852794377
# previous_NAME_CASH_LOAN_PURPOSE_Refusal to name the goal_sum : 0.003171875418412702
# ORGANIZATION_TYPE_Business Entity Type 2 : 0.0031513134363271153
# previous_CHANNEL_TYPE_Car dealer_mean : -0.003148433409799071
# previous_SELLERPLACE_AREA_max : -0.003134522708945463
# previous_NAME_GOODS_CATEGORY_Fitness_sum : -0.003123782712089007
# ORGANIZATION_TYPE_Trade: type 2 : -0.0031056384457146652
# previous_CODE_REJECT_REASON_VERIF_sum : 0.0030936893036369265
# bureau_CNT_CREDIT_PROLONG_mean : 0.003030874489614793
# previous_NAME_GOODS_CATEGORY_Sport and Leisure_sum : -0.003019824058622745
# previous_NAME_GOODS_CATEGORY_Auto Accessories_mean : 0.0029902433779487297
# previous_NAME_CASH_LOAN_PURPOSE_Money for a third person_sum : 0.0029817228548082446
# ORGANIZATION_TYPE_Electricity : -0.0029454687194138155
# bureau_CREDIT_CURRENCY_currency 3_sum : 0.0029230554659072103
# ORGANIZATION_TYPE_Industry: type 13 : 0.00290449785116487
# previous_NAME_GOODS_CATEGORY_Jewelry_mean : 0.0028227841422449325
# LIVE_REGION_NOT_WORK_REGION : 0.0028186879966308016
# NAME_EDUCATION_TYPE_Incomplete higher : 0.002817548727401485
# previous_NAME_GOODS_CATEGORY_Insurance_mean : 0.002807755384342808
# previous_NAME_SELLER_INDUSTRY_MLM partners_sum : -0.0027945368016728204
# bureau_CREDIT_CURRENCY_currency 3_mean : 0.0027824928125779694
# bureau_CREDIT_TYPE_Loan for business development_mean : -0.002758903409607717
# client_installments_AMT_INSTALMENT_max_sum : 0.002752022378758339
# previous_PRODUCT_COMBINATION_POS others without interest_sum : -0.0027395848260151345
# bureau_CREDIT_TYPE_Real estate loan_sum : -0.002704381897616616
# AMT_REQ_CREDIT_BUREAU_DAY : 0.0027041282607189157
# previous_NAME_TYPE_SUITE_Other_A_sum : 0.002678509000930553
# FLAG_DOCUMENT_4 : -0.002672118455773827
# FONDKAPREMONT_MODE_not specified : -0.0026678875130933385
# previous_PRODUCT_COMBINATION_POS mobile without interest_sum : -0.0026542625028798785
# NAME_TYPE_SUITE_Children : -0.0026482236678303304
# OCCUPATION_TYPE_HR staff : -0.0026390733287498178
# client_cash_NAME_CONTRACT_STATUS_Signed_sum_max : -0.0026361325525192545
# client_credit_AMT_INST_MIN_REGULARITY_sum_min : 0.002633825141097332
# ORGANIZATION_TYPE_Trade: type 4 : -0.0026205806418660178
# previous_WEEKDAY_APPR_PROCESS_START_SUNDAY_sum : -0.0026162303670463883
# previous_NAME_TYPE_SUITE_Unaccompanied_sum : 0.0025899959945495147
# previous_PRODUCT_COMBINATION_Cash Street: low_mean : 0.0025860976435640327
# previous_NAME_TYPE_SUITE_Other_B_mean : 0.0025852654984799346
# previous_PRODUCT_COMBINATION_POS mobile without interest_mean : -0.0025642507278178946
# bureau_AMT_ANNUITY_min : -0.0025423684088860554
# previous_NAME_PRODUCT_TYPE_x-sell_sum : -0.002530785359952733
# client_credit_AMT_PAYMENT_TOTAL_CURRENT_min_min : 0.0024958239031852205
# bureau_AMT_CREDIT_MAX_OVERDUE_sum : 0.002490956081536365
# bureau_CREDIT_TYPE_Unknown type of loan_mean : -0.0024760378175608198
# OCCUPATION_TYPE_Secretaries : -0.002451963278810472
# OCCUPATION_TYPE_IT staff : -0.002445027723665992
# previous_CODE_REJECT_REASON_SYSTEM_sum : -0.002404557587531866
# WEEKDAY_APPR_PROCESS_START_SATURDAY : -0.0023976950017315056
# previous_NAME_GOODS_CATEGORY_Additional Service_mean : -0.0023552996215686663
# client_credit_NAME_CONTRACT_STATUS_Approved_mean_max : -0.0023345083959518767
# client_installments_NUM_INSTALMENT_NUMBER_min_min : -0.0023344224234143848
# bureau_AMT_CREDIT_MAX_OVERDUE_min : 0.0023289563873452987
# client_installments_AMT_INSTALMENT_max_max : 0.0023234354972203517
# NAME_INCOME_TYPE_Student : -0.002267341887765188
# bureau_CREDIT_TYPE_Unknown type of loan_sum : -0.0022652912637313284
# previous_NAME_GOODS_CATEGORY_Education_mean : -0.002245932882005795
# client_cash_NAME_CONTRACT_STATUS_Approved_sum_sum : -0.002195856561077366
# bureau_AMT_CREDIT_SUM_DEBT_max : -0.0021730847999757693
# previous_NAME_TYPE_SUITE_Other_B_sum : 0.002163244531335239
# previous_PRODUCT_COMBINATION_POS others without interest_mean : -0.002154640390615527
# client_cash_NAME_CONTRACT_STATUS_Approved_sum_max : -0.002132973708362881
# client_credit_CNT_DRAWINGS_OTHER_CURRENT_min_sum : -0.0020902560568723974
# client_cash_CNT_INSTALMENT_min_max : -0.00208776013208111
# client_cash_NAME_CONTRACT_STATUS_Approved_mean_min : 0.002063557140365648
# previous_NAME_CASH_LOAN_PURPOSE_Everyday expenses_mean : 0.002057689594804402
# AMT_REQ_CREDIT_BUREAU_QRT : -0.0020220179941557188
# previous_CHANNEL_TYPE_Country-wide_sum : 0.0020123738674363194
# ORGANIZATION_TYPE_Industry: type 11 : 0.0020082875485395867
# client_cash_NAME_CONTRACT_STATUS_Canceled_mean_sum : 0.0020005463130094983
# ORGANIZATION_TYPE_Industry: type 5 : -0.0019918464988398815
# client_credit_NAME_CONTRACT_STATUS_Refused_mean_max : 0.0019868456018317573
# previous_NAME_SELLER_INDUSTRY_Jewelry_mean : 0.001985102945973307
# bureau_CREDIT_TYPE_Real estate loan_mean : -0.0019049886555531144
# client_cash_NAME_CONTRACT_STATUS_Approved_sum_min : 0.0019040144460863897
# client_credit_AMT_DRAWINGS_OTHER_CURRENT_min_sum : -0.0018932168517390062
# previous_NAME_SELLER_INDUSTRY_Jewelry_sum : 0.0018789489507254119
# client_installments_DAYS_ENTRY_PAYMENT_sum_max : 0.0018496307981635696
# previous_NAME_TYPE_SUITE_Group of people_sum : 0.001841302718927049
# bureau_CREDIT_TYPE_Another type of loan_mean : -0.0017613501082517733
# FLAG_EMAIL : -0.0017593303703844925
# client_credit_AMT_DRAWINGS_CURRENT_min_sum : 0.0017343842304556776
# WALLSMATERIAL_MODE_Mixed : -0.0017133474892546316
# bureau_CREDIT_CURRENCY_currency 4_sum : -0.001691662874945505
# NAME_INCOME_TYPE_Businessman : -0.001689954879284071
# previous_NAME_CLIENT_TYPE_XNA_mean : 0.001687534904067832
# previous_NAME_CASH_LOAN_PURPOSE_Journey_mean : 0.0016744498909919817
# bureau_CREDIT_TYPE_Loan for working capital replenishment_mean : 0.0016049280712758655
# client_credit_AMT_DRAWINGS_OTHER_CURRENT_max_sum : -0.0015509700341056285
# previous_NAME_GOODS_CATEGORY_Computers_sum : -0.0015275285866485893
# FLAG_DOCUMENT_7 : -0.001519557429110956
# client_credit_AMT_DRAWINGS_POS_CURRENT_min_sum : -0.0014812737261396915
# ORGANIZATION_TYPE_Emergency : -0.001458368187564117
# previous_NAME_GOODS_CATEGORY_Education_sum : -0.0014571035488531627
# NAME_TYPE_SUITE_Spouse, partner : -0.0014485849995074906
# WEEKDAY_APPR_PROCESS_START_WEDNESDAY : 0.0014457530803296573
# bureau_CREDIT_CURRENCY_currency 4_mean : -0.001443781595173105
# ORGANIZATION_TYPE_Industry: type 8 : 0.001435711462470302
# previous_CHANNEL_TYPE_Country-wide_mean : -0.0014256836601588328
# FLAG_DOCUMENT_10 : -0.001413910796980944
# client_credit_AMT_PAYMENT_TOTAL_CURRENT_min_sum : 0.0014138866932130619
# client_cash_NAME_CONTRACT_STATUS_Signed_sum_sum : -0.0014108546909571233
# bureau_AMT_ANNUITY_mean : -0.0013914379088957028
# client_cash_NAME_CONTRACT_STATUS_Approved_mean_max : -0.001386118987743617
# NAME_TYPE_SUITE_Other_A : 0.0013713777660814732
# FLAG_DOCUMENT_19 : -0.0013576131686514454
# previous_NAME_CASH_LOAN_PURPOSE_Buying a new car_mean : 0.001354227885218541
# client_credit_AMT_CREDIT_LIMIT_ACTUAL_min_min : -0.0013520347709322523
# previous_NAME_CASH_LOAN_PURPOSE_Business development_mean : 0.001349385241257891
# ORGANIZATION_TYPE_Religion : -0.0013371284153124554
# client_cash_CNT_INSTALMENT_min_mean : 0.0013087650919169098
# previous_SELLERPLACE_AREA_min : -0.0012943936000757103
# previous_NAME_CASH_LOAN_PURPOSE_Furniture_mean : 0.001269332225771451
# ORGANIZATION_TYPE_Mobile : 0.0012679676278117948
# previous_NAME_GOODS_CATEGORY_Direct Sales_mean : 0.0012606833727062663
# WEEKDAY_APPR_PROCESS_START_SUNDAY : -0.0012451992453431046
# ORGANIZATION_TYPE_Industry: type 2 : -0.0012302212009010092
# WEEKDAY_APPR_PROCESS_START_FRIDAY : 0.0012060496488303111
# previous_NAME_CASH_LOAN_PURPOSE_Refusal to name the goal_mean : 0.0011868811348668983
# bureau_CREDIT_TYPE_Another type of loan_sum : -0.0011862659061047645
# NAME_FAMILY_STATUS_Separated : 0.0011666398780208376
# ORGANIZATION_TYPE_Industry: type 10 : -0.0011412028453416582
# previous_NAME_GOODS_CATEGORY_Additional Service_sum : -0.0011398647073976322
# bureau_CREDIT_TYPE_Loan for purchase of shares (margin lending)_sum : -0.0011277645492692818
# ORGANIZATION_TYPE_Postal : 0.001125053206696475
# bureau_AMT_ANNUITY_max : 0.0011202788718043927
# client_bureau_balance_STATUS_X_mean_max : 0.0011102672250508485
# client_cash_NAME_CONTRACT_STATUS_Canceled_sum_min : -0.0011081788359458603
# previous_NAME_TYPE_SUITE_Group of people_mean : 0.001085971708345323
# client_bureau_balance_STATUS_X_mean_min : -0.0010564111036835966
# bureau_CREDIT_TYPE_Cash loan (non-earmarked)_sum : -0.001053799352862261
# previous_NAME_CASH_LOAN_PURPOSE_Buying a garage_sum : -0.0010535084021147504
# previous_NAME_CASH_LOAN_PURPOSE_Buying a new car_sum : 0.0010517420262439257
# ORGANIZATION_TYPE_Trade: type 1 : 0.001031778494079437
# HOUSETYPE_MODE_terraced house : 0.0009822052308761538
# bureau_CREDIT_TYPE_Cash loan (non-earmarked)_mean : -0.0009689452500854792
# AMT_REQ_CREDIT_BUREAU_HOUR : 0.0009300931246866118
# client_cash_NAME_CONTRACT_STATUS_Canceled_mean_min : -0.0009242410502644011
# previous_NAME_CONTRACT_STATUS_Unused offer_mean : 0.0009224717107722724
# previous_NAME_GOODS_CATEGORY_Insurance_sum : 0.0009205677725980654
# previous_NAME_GOODS_CATEGORY_Weapon_mean : -0.0009184051719275109
# ORGANIZATION_TYPE_Trade: type 5 : -0.0009039009683546354
# bureau_CREDIT_TYPE_Loan for purchase of shares (margin lending)_mean : -0.0009026481845391592
# client_credit_NAME_CONTRACT_STATUS_Demand_mean_min : 0.0008992297362894116
# ORGANIZATION_TYPE_Transport: type 2 : -0.0008389662704717262
# AMT_REQ_CREDIT_BUREAU_WEEK : 0.0007869822350193809
# client_cash_NAME_CONTRACT_STATUS_XNA_mean_mean : -0.0007835642655301553
# previous_NAME_CASH_LOAN_PURPOSE_Buying a home_mean : 0.0007770444949198558
# FLAG_DOCUMENT_12 : -0.0007557609667368717
# NAME_FAMILY_STATUS_Unknown : -0.0007557609667363978
# client_cash_NAME_CONTRACT_STATUS_Canceled_mean_max : -0.0007471037317558428
# previous_NAME_GOODS_CATEGORY_Sport and Leisure_mean : -0.0007169683631873401
# ORGANIZATION_TYPE_Telecom : -0.0007119744351323772
# client_cash_NAME_CONTRACT_STATUS_Approved_mean_mean : 0.0006981992923592965
# previous_NAME_CASH_LOAN_PURPOSE_Buying a garage_mean : 0.0006802162792461117
# previous_CODE_REJECT_REASON_VERIF_mean : 0.0006795027348997897
# previous_CODE_REJECT_REASON_SYSTEM_mean : -0.0006729494054929165
# ORGANIZATION_TYPE_Industry: type 6 : -0.0006517266451134378
# bureau_AMT_CREDIT_SUM_DEBT_mean : -0.000637472000848305
# WALLSMATERIAL_MODE_Others : 0.0006279629397058768
# client_cash_NAME_CONTRACT_STATUS_Signed_mean_max : -0.0005823498792850806
# client_credit_CNT_DRAWINGS_OTHER_CURRENT_mean_sum : 0.0005661754559237559
# bureau_CREDIT_TYPE_Interbank credit_mean : -0.0005638790644929998
# bureau_CREDIT_TYPE_Mobile operator loan_mean : -0.0005638790644916259
# client_installments_NUM_INSTALMENT_NUMBER_sum_min : -0.0005570761737382688
# previous_NAME_GOODS_CATEGORY_Animals_mean : -0.0005537179995116051
# FLAG_MOBIL : 0.0005344028355900263
# previous_NFLAG_INSURED_ON_APPROVAL_mean : -0.0005239101042835428
# previous_NAME_CONTRACT_STATUS_Unused offer_sum : 0.0005159984374777603
# client_credit_NAME_CONTRACT_STATUS_Signed_mean_min : 0.0005136046901729732
# client_cash_NAME_CONTRACT_STATUS_Completed_sum_mean : -0.0004694704522077489
# previous_PRODUCT_COMBINATION_POS other with interest_sum : -0.00046870101875369415
# ORGANIZATION_TYPE_Housing : -0.0004646197649154066
# NAME_TYPE_SUITE_Group of people : 0.00045145340991005565
# WEEKDAY_APPR_PROCESS_START_THURSDAY : 0.00044677993630574893
# client_cash_NAME_CONTRACT_STATUS_Completed_mean_mean : 0.0004331888748433376
# client_bureau_balance_STATUS_X_mean_mean : 0.00040819010791833703
# previous_NAME_TYPE_SUITE_Spouse, partner_sum : 0.0004069296592045686
# OCCUPATION_TYPE_Realty agents : -0.0003937625620374322
# client_cash_NAME_CONTRACT_STATUS_Approved_sum_mean : -0.0003934676898737053
# FLAG_CONT_MOBILE : 0.0003702937157363586
# previous_NAME_CASH_LOAN_PURPOSE_XNA_mean : -0.000357189009828134
# client_installments_NUM_INSTALMENT_VERSION_sum_min : 0.0003529641276388175
# ORGANIZATION_TYPE_Business Entity Type 1 : 0.0003451126464525603
# previous_WEEKDAY_APPR_PROCESS_START_TUESDAY_mean : 0.0003334639445543101
# FLAG_DOCUMENT_5 : -0.00031625516626845456
# NAME_HOUSING_TYPE_Co-op apartment : -0.0003126003799436073
# previous_RATE_INTEREST_PRIMARY_sum : -0.00029542295665339516
# bureau_CREDIT_TYPE_Loan for the purchase of equipment_mean : 0.00028645459520105604
# previous_NAME_PAYMENT_TYPE_Non-cash from your account_mean : 0.00025337974162988714
# bureau_AMT_CREDIT_SUM_DEBT_min : 0.00024139689669648885
# previous_NAME_GOODS_CATEGORY_Weapon_sum : -0.00024129926747548387
# ORGANIZATION_TYPE_Legal Services : -0.00023611066491417495
# previous_NAME_GOODS_CATEGORY_Office Appliances_mean : -0.00023597248515822583
# previous_RATE_INTEREST_PRIVILEGED_sum : 0.0002239565788299769
# FLAG_DOCUMENT_20 : 0.0002153068377039733
# previous_NAME_PAYMENT_TYPE_Cashless from the account of the employer_sum : -0.00019124901042557487
# previous_NAME_GOODS_CATEGORY_Office Appliances_sum : 0.00019051404510749963
# bureau_CNT_CREDIT_PROLONG_min : -0.00018208807827986779
# previous_NAME_CASH_LOAN_PURPOSE_Money for a third person_mean : 0.00012114040511567334
# ORGANIZATION_TYPE_Advertising : 0.00011733819179510517
# ORGANIZATION_TYPE_Industry: type 7 : -9.430461096018596e-05
# previous_NAME_PAYMENT_TYPE_Non-cash from your account_sum : 8.251404960824144e-05
# previous_NAME_PAYMENT_TYPE_Cashless from the account of the employer_mean : 5.7581331793265954e-05
# previous_NAME_GOODS_CATEGORY_Direct Sales_sum : -1.1140836742869191e-05
# bureau_AMT_CREDIT_SUM_OVERDUE_min : 3.2886287532103866e-06
# previous_NAME_GOODS_CATEGORY_House Construction_mean : nan
# previous_NAME_GOODS_CATEGORY_House Construction_sum : nan
# client_credit_SK_DPD_min_mean : nan
# client_credit_SK_DPD_min_sum : nan
# client_cash_NAME_CONTRACT_STATUS_XNA_mean_min : nan

# %%
sorted_corr = correlations.abs().sort_values(ascending=False)

# %%
sorted_corr[250:].index.values.tolist()
# Out:
# ['TARGET',
#  'EXT_SOURCE_3',
#  'EXT_SOURCE_2',
#  'EXT_SOURCE_1',
#  'client_credit_CNT_DRAWINGS_CURRENT_max_min',
#  'bureau_DAYS_CREDIT_mean',
#  'client_credit_CNT_DRAWINGS_CURRENT_mean_mean',
#  'DAYS_BIRTH',
#  'previous_NAME_CONTRACT_STATUS_Refused_mean',
#  'bureau_CREDIT_ACTIVE_Active_mean',
#  'bureau_DAYS_CREDIT_min',
#  'DAYS_EMPLOYED',
#  'client_credit_AMT_INST_MIN_REGULARITY_mean_min',
#  'bureau_DAYS_CREDIT_UPDATE_mean',
#  'client_bureau_balance_MONTHS_BALANCE_sum_min',
#  'bureau_CREDIT_ACTIVE_Active_sum',
#  'previous_NAME_CONTRACT_STATUS_Refused_sum',
#  'client_credit_AMT_RECIVABLE_min_min',
#  'previous_NAME_CONTRACT_STATUS_Approved_mean',
#  'client_bureau_balance_STATUS_C_sum_mean',
#  'client_credit_AMT_INST_MIN_REGULARITY_max_min',
#  'previous_NAME_PRODUCT_TYPE_walk-in_sum',
#  'client_bureau_balance_STATUS_1_mean_mean',
#  'client_bureau_balance_STATUS_1_mean_max',
#  'client_bureau_balance_STATUS_C_sum_max',
#  'REGION_RATING_CLIENT',
#  'client_credit_AMT_DRAWINGS_CURRENT_mean_min',
#  'client_installments_AMT_PAYMENT_min_sum',
#  'NAME_INCOME_TYPE_Working',
#  'previous_NAME_PRODUCT_TYPE_walk-in_mean',
#  'client_credit_MONTHS_BALANCE_sum_sum',
#  'NAME_EDUCATION_TYPE_Higher education',
#  'previous_CODE_REJECT_REASON_SCOFR_sum',
#  'client_bureau_balance_STATUS_C_mean_mean',
#  'bureau_DAYS_ENDDATE_FACT_min',
#  'previous_CODE_REJECT_REASON_SCOFR_mean',
#  'DAYS_LAST_PHONE_CHANGE',
#  'CODE_GENDER',
#  'previous_CODE_REJECT_REASON_HC_mean',
#  'client_bureau_balance_MONTHS_BALANCE_mean_min',
#  'bureau_DAYS_CREDIT_ENDDATE_sum',
#  'previous_DAYS_DECISION_min',
#  'bureau_DAYS_ENDDATE_FACT_mean',
#  'client_bureau_balance_STATUS_1_mean_sum',
#  'client_credit_MONTHS_BALANCE_max_sum',
#  'client_credit_AMT_DRAWINGS_CURRENT_max_min',
#  'DAYS_ID_PUBLISH',
#  'client_credit_AMT_CREDIT_LIMIT_ACTUAL_max_sum',
#  'client_credit_AMT_CREDIT_LIMIT_ACTUAL_sum_sum',
#  'REG_CITY_NOT_WORK_CITY',
#  'NAME_EDUCATION_TYPE_Secondary / secondary special',
#  'client_credit_CNT_DRAWINGS_ATM_CURRENT_sum_min',
#  'bureau_DAYS_CREDIT_max',
#  'client_bureau_balance_STATUS_C_sum_sum',
#  'previous_DAYS_FIRST_DRAWING_mean',
#  'previous_PRODUCT_COMBINATION_Card Street_sum',
#  'previous_CODE_REJECT_REASON_HC_sum',
#  'bureau_DAYS_CREDIT_ENDDATE_mean',
#  'previous_DAYS_DECISION_mean',
#  'NAME_INCOME_TYPE_Pensioner',
#  'previous_NAME_CLIENT_TYPE_New_sum',
#  'ORGANIZATION_TYPE_XNA',
#  'FLAG_EMP_PHONE',
#  'client_credit_AMT_CREDIT_LIMIT_ACTUAL_sum_min',
#  'previous_NAME_CONTRACT_TYPE_Revolving loans_sum',
#  'client_installments_DAYS_ENTRY_PAYMENT_min_mean',
#  'previous_DAYS_FIRST_DRAWING_min',
#  'previous_DAYS_FIRST_DUE_min',
#  'bureau_CREDIT_TYPE_Microloan_mean',
#  'REG_CITY_NOT_LIVE_CITY',
#  'FLAG_DOCUMENT_3',
#  'client_bureau_balance_STATUS_0_mean_mean',
#  'client_bureau_balance_STATUS_C_mean_max',
#  'FLOORSMAX_AVG',
#  'OCCUPATION_TYPE_Laborers',
#  'bureau_DAYS_CREDIT_UPDATE_min',
#  'previous_NAME_YIELD_GROUP_XNA_mean',
#  'EMERGENCYSTATE_MODE_No',
#  'bureau_DAYS_CREDIT_sum',
#  'DAYS_REGISTRATION',
#  'client_installments_AMT_PAYMENT_min_mean',
#  'previous_RATE_DOWN_PAYMENT_sum',
#  'previous_NAME_PORTFOLIO_Cards_sum',
#  'previous_NAME_YIELD_GROUP_low_normal_mean',
#  'HOUSETYPE_MODE_block of flats',
#  'previous_CODE_REJECT_REASON_LIMIT_sum',
#  'previous_PRODUCT_COMBINATION_Card Street_mean',
#  'previous_RATE_DOWN_PAYMENT_max',
#  'client_credit_AMT_DRAWINGS_ATM_CURRENT_count_min',
#  'previous_CODE_REJECT_REASON_LIMIT_mean',
#  'client_cash_CNT_INSTALMENT_FUTURE_mean_min',
#  'client_credit_CNT_DRAWINGS_POS_CURRENT_sum_min',
#  'client_installments_AMT_INSTALMENT_min_sum',
#  'client_credit_AMT_DRAWINGS_ATM_CURRENT_sum_min',
#  'OWN_CAR_AGE',
#  'previous_NAME_YIELD_GROUP_high_mean',
#  'previous_PRODUCT_COMBINATION_Cash X-Sell: low_mean',
#  'client_bureau_balance_STATUS_1_mean_min',
#  'REGION_POPULATION_RELATIVE',
#  'client_cash_MONTHS_BALANCE_min_sum',
#  'previous_NAME_YIELD_GROUP_high_sum',
#  'client_credit_CNT_DRAWINGS_POS_CURRENT_max_sum',
#  'bureau_DAYS_CREDIT_ENDDATE_max',
#  'previous_PRODUCT_COMBINATION_Cash X-Sell: high_sum',
#  'previous_HOUR_APPR_PROCESS_START_mean',
#  'client_bureau_balance_STATUS_0_sum_mean',
#  'client_cash_NAME_CONTRACT_STATUS_Active_mean_sum',
#  'previous_NAME_PAYMENT_TYPE_XNA_mean',
#  'previous_AMT_ANNUITY_mean',
#  'previous_CHANNEL_TYPE_AP+ (Cash loan)_mean',
#  'bureau_CREDIT_TYPE_Credit card_sum',
#  'client_cash_MONTHS_BALANCE_min_mean',
#  'previous_CHANNEL_TYPE_AP+ (Cash loan)_sum',
#  'bureau_CREDIT_TYPE_Credit card_mean',
#  'previous_DAYS_LAST_DUE_1ST_VERSION_mean',
#  'client_cash_MONTHS_BALANCE_sum_min',
#  'bureau_DAYS_CREDIT_ENDDATE_min',
#  'ELEVATORS_AVG',
#  'bureau_CREDIT_TYPE_Microloan_sum',
#  'previous_PRODUCT_COMBINATION_POS industry with interest_mean',
#  'FLOORSMIN_AVG',
#  'previous_RATE_DOWN_PAYMENT_mean',
#  'client_credit_AMT_RECIVABLE_min_sum',
#  'client_bureau_balance_STATUS_X_sum_mean',
#  'client_bureau_balance_STATUS_1_sum_mean',
#  'WALLSMATERIAL_MODE_Panel',
#  'LIVE_CITY_NOT_WORK_CITY',
#  'DEF_30_CNT_SOCIAL_CIRCLE',
#  'previous_AMT_ANNUITY_min',
#  'client_installments_NUM_INSTALMENT_NUMBER_max_min',
#  'client_installments_NUM_INSTALMENT_VERSION_min_min',
#  'client_credit_CNT_INSTALMENT_MATURE_CUM_min_min',
#  'previous_DAYS_FIRST_DRAWING_count',
#  'previous_PRODUCT_COMBINATION_Cash Street: high_sum',
#  'previous_NAME_PORTFOLIO_Cards_mean',
#  'client_bureau_balance_STATUS_0_mean_min',
#  'previous_NAME_CASH_LOAN_PURPOSE_Repairs_sum',
#  'previous_HOUR_APPR_PROCESS_START_min',
#  'DEF_60_CNT_SOCIAL_CIRCLE',
#  'client_bureau_balance_STATUS_0_sum_max',
#  'client_bureau_balance_STATUS_0_mean_sum',
#  'client_bureau_balance_STATUS_X_sum_max',
#  'NAME_CONTRACT_TYPE',
#  'previous_HOUR_APPR_PROCESS_START_max',
#  'previous_PRODUCT_COMBINATION_POS industry with interest_sum',
#  'bureau_DAYS_ENDDATE_FACT_count',
#  'AMT_CREDIT',
#  'OCCUPATION_TYPE_Drivers',
#  'client_bureau_balance_MONTHS_BALANCE_sum_max',
#  'previous_NAME_GOODS_CATEGORY_Furniture_mean',
#  'previous_PRODUCT_COMBINATION_Cash X-Sell: high_mean',
#  'previous_PRODUCT_COMBINATION_Cash Street: high_mean',
#  'client_installments_NUM_INSTALMENT_VERSION_mean_sum',
#  'client_bureau_balance_STATUS_C_mean_sum',
#  'NAME_HOUSING_TYPE_With parents',
#  'client_bureau_balance_STATUS_0_mean_max',
#  'APARTMENTS_AVG',
#  'previous_CNT_PAYMENT_max',
#  'previous_NAME_PORTFOLIO_XNA_mean',
#  'previous_NAME_CASH_LOAN_PURPOSE_Urgent needs_sum',
#  'previous_NAME_YIELD_GROUP_low_action_mean',
#  'client_credit_CNT_INSTALMENT_MATURE_CUM_mean_min',
#  'ORGANIZATION_TYPE_Self-employed',
#  'previous_AMT_ANNUITY_max',
#  'previous_NAME_GOODS_CATEGORY_Furniture_sum',
#  'previous_NAME_SELLER_INDUSTRY_Furniture_mean',
#  'FLAG_DOCUMENT_6',
#  'NAME_HOUSING_TYPE_House / apartment',
#  'FLAG_WORK_PHONE',
#  'previous_NAME_SELLER_INDUSTRY_Connectivity_mean',
#  'client_bureau_balance_STATUS_C_mean_min',
#  'bureau_DAYS_CREDIT_UPDATE_max',
#  'client_installments_NUM_INSTALMENT_VERSION_mean_min',
#  'previous_NAME_YIELD_GROUP_low_normal_sum',
#  'client_credit_AMT_PAYMENT_TOTAL_CURRENT_max_min',
#  'client_cash_CNT_INSTALMENT_FUTURE_mean_mean',
#  'previous_CNT_PAYMENT_mean',
#  'previous_CNT_PAYMENT_sum',
#  'OCCUPATION_TYPE_Low-skill Laborers',
#  'previous_DAYS_LAST_DUE_min',
#  'previous_DAYS_LAST_DUE_mean',
#  'previous_PRODUCT_COMBINATION_Cash Street: middle_sum',
#  'client_installments_NUM_INSTALMENT_VERSION_mean_mean',
#  'client_bureau_balance_STATUS_1_sum_max',
#  'previous_DAYS_LAST_DUE_1ST_VERSION_sum',
#  'previous_NAME_CLIENT_TYPE_Refreshed_mean',
#  'NAME_FAMILY_STATUS_Single / not married',
#  'previous_DAYS_LAST_DUE_1ST_VERSION_min',
#  'bureau_CREDIT_TYPE_Consumer credit_mean',
#  'client_installments_AMT_PAYMENT_min_min',
#  'previous_NAME_SELLER_INDUSTRY_Furniture_sum',
#  'client_bureau_balance_STATUS_1_sum_sum',
#  'client_installments_AMT_PAYMENT_sum_max',
#  'previous_AMT_DOWN_PAYMENT_max',
#  'client_credit_MONTHS_BALANCE_max_mean',
#  'NAME_FAMILY_STATUS_Married',
#  'previous_NAME_YIELD_GROUP_low_action_sum',
#  'client_credit_CNT_DRAWINGS_CURRENT_min_min',
#  'client_installments_NUM_INSTALMENT_VERSION_mean_max',
#  'previous_NAME_SELLER_INDUSTRY_XNA_mean']

# %%
df = pd.read_csv('preprocessed-75.csv').drop(columns=[sorted_corr[250:].index.values.tolist()])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-93-c46ac24e2f2d> in <module>
# ----> 1 df = pd.read_csv('preprocessed-75.csv').drop(columns=[sorted_corr[250:].index.values.tolist()])
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# /usr/local/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# /usr/local/lib/python3.7/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3968                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3969             else:
# -> 3970                 new_axis = axis.drop(labels, errors=errors)
#    3971             result = self.reindex(**{axis_name: new_axis})
#    3972
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5015         if mask.any():
#    5016             if errors != "ignore":
# -> 5017                 raise KeyError(f"{labels[mask]} not found in axis")
#    5018             indexer = indexer[~mask]
#    5019         return self.delete(indexer)
#
# KeyError: "[('OCCUPATION_TYPE_Core staff', 'client_credit_NAME_CONTRACT_STATUS_Completed_mean_sum', 'client_bureau_balance_MONTHS_BALANCE_max_min', 'bureau_CREDIT_TYPE_Car loan_mean', 'client_credit_AMT_CREDIT_LIMIT_ACTUAL_min_sum', 'bureau_AMT_CREDIT_SUM_mean', 'client_cash_NAME_CONTRACT_STATUS_Active_sum_sum', 'AMT_REQ_CREDIT_BUREAU_YEAR', 'client_cash_CNT_INSTALMENT_min_min', 'ORGANIZATION_TYPE_Construction', 'NAME_HOUSING_TYPE_Rented apartment', 'previous_NAME_SELLER_INDUSTRY_Clothing_sum', 'bureau_AMT_CREDIT_SUM_max', 'previous_DAYS_DECISION_sum', 'bureau_DAYS_ENDDATE_FACT_max', 'client_cash_NAME_CONTRACT_STATUS_Completed_mean_sum', 'OCCUPATION_TYPE_Sales staff', 'client_cash_NAME_CONTRACT_STATUS_Completed_mean_max', 'previous_AMT_CREDIT_min', 'client_cash_NAME_CONTRACT_STATUS_Completed_mean_min', 'NAME_FAMILY_STATUS_Widow', 'client_credit_AMT_PAYMENT_CURRENT_min_sum', 'previous_NAME_GOODS_CATEGORY_Consumer Electronics_mean', 'client_credit_CNT_DRAWINGS_ATM_CURRENT_min_sum', 'client_bureau_balance_STATUS_0_sum_sum', 'CNT_CHILDREN', 'ENTRANCES_AVG', 'previous_NAME_CASH_LOAN_PURPOSE_Other_mean', 'previous_NAME_CASH_LOAN_PURPOSE_Urgent needs_mean', 'previous_DAYS_FIRST_DUE_max', 'client_cash_CNT_INSTALMENT_FUTURE_min_min', 'client_bureau_balance_STATUS_5_mean_mean', 'client_bureau_balance_STATUS_5_mean_min', 'previous_CHANNEL_TYPE_Credit and cash offices_sum', 'previous_NAME_SELLER_INDUSTRY_Consumer electronics_sum', 'OCCUPATION_TYPE_Managers', 'previous_PRODUCT_COMBINATION_Cash_mean', 'client_bureau_balance_STATUS_2_mean_mean', 'COMMONAREA_AVG', 'client_cash_CNT_INSTALMENT_FUTURE_min_mean', 'previous_PRODUCT_COMBINATION_Cash Street: middle_mean', 'previous_CHANNEL_TYPE_Stone_sum', 'previous_NAME_GOODS_CATEGORY_Mobile_mean', 'previous_NAME_PRODUCT_TYPE_x-sell_mean', 'client_cash_CNT_INSTALMENT_FUTURE_mean_max', 'previous_PRODUCT_COMBINATION_Card X-Sell_sum', 'client_bureau_balance_STATUS_2_mean_max', 'client_cash_MONTHS_BALANCE_sum_sum', 'ORGANIZATION_TYPE_Transport: type 3', 'client_bureau_balance_STATUS_0_sum_min', 'client_bureau_balance_STATUS_3_mean_mean', 'client_installments_AMT_PAYMENT_sum_sum', 'client_bureau_balance_STATUS_3_sum_mean', 'previous_NAME_TYPE_SUITE_Children_sum', 'client_cash_NAME_CONTRACT_STATUS_Active_sum_min', 'previous_AMT_DOWN_PAYMENT_min', 'client_bureau_balance_STATUS_3_mean_max', 'bureau_CREDIT_ACTIVE_Sold_mean', 'client_installments_NUM_INSTALMENT_VERSION_sum_max', 'client_bureau_balance_STATUS_4_mean_max', 'client_credit_AMT_DRAWINGS_POS_CURRENT_sum_sum', 'previous_DAYS_DECISION_max', 'previous_NAME_TYPE_SUITE_Children_mean', 'client_bureau_balance_STATUS_4_sum_mean', 'client_bureau_balance_STATUS_4_mean_mean', 'previous_AMT_CREDIT_mean', 'previous_NAME_CASH_LOAN_PURPOSE_Payments on other loans_sum', 'previous_NAME_YIELD_GROUP_middle_mean', 'client_installments_NUM_INSTALMENT_NUMBER_mean_min', 'previous_NAME_TYPE_SUITE_Family_sum', 'client_bureau_balance_STATUS_4_mean_sum', 'client_bureau_balance_STATUS_3_mean_sum', 'previous_NAME_PORTFOLIO_Cash_sum', 'previous_PRODUCT_COMBINATION_Cash X-Sell: middle_mean', 'previous_NFLAG_INSURED_ON_APPROVAL_sum', 'client_installments_NUM_INSTALMENT_VERSION_sum_sum', 'client_bureau_balance_STATUS_4_sum_sum', 'bureau_AMT_ANNUITY_count', 'previous_NAME_SELLER_INDUSTRY_Construction_mean', 'client_credit_AMT_DRAWINGS_CURRENT_sum_sum', 'client_bureau_balance_STATUS_5_sum_min', 'client_bureau_balance_STATUS_4_sum_max', 'client_cash_NAME_CONTRACT_STATUS_Signed_mean_min', 'previous_WEEKDAY_APPR_PROCESS_START_THURSDAY_sum', 'previous_NAME_CASH_LOAN_PURPOSE_Car repairs_sum', 'previous_RATE_DOWN_PAYMENT_min', 'previous_CODE_REJECT_REASON_SCO_sum', 'OCCUPATION_TYPE_Security staff', 'client_bureau_balance_STATUS_X_sum_min', 'client_installments_AMT_PAYMENT_min_max', 'client_credit_CNT_DRAWINGS_CURRENT_min_sum', 'previous_WEEKDAY_APPR_PROCESS_START_MONDAY_sum', 'ANNUITY_INCOME_PERCENT', 'previous_PRODUCT_COMBINATION_POS mobile with interest_sum', 'client_cash_NAME_CONTRACT ...

# %%
len(df.columns)
# Out:
# 729

# %%
len(random_forest.feature_importances_)
# Out:
# 848
